# %% [markdown]
# # Lab assignment №1, part 3
#
# This lab assignment consists of several parts. You are supposed to make some transformations, train some models, estimate the quality of the models and explain your results.
#
# Several comments:
# * Don't hesitate to ask questions, it's a good practice.
# * No private/public sharing, please. The copied assignments will be graded with 0 points.
# * Blocks of this lab will be graded separately.

# %% [markdown]
# __*This is the third part of the assignment. First and second parts are waiting for you in the same directory.*__

# %% [markdown]
# ##  Part 3. SVM and kernels

# %% [markdown]
# Kernels concept get adopted in variety of ML algorithms (e.g. Kernel PCA, Gaussian Processes, kNN, ...).
#
# So in this task you are to examine kernels for SVM algorithm applied to rather simple artificial datasets.
#
# To make it clear: we will work with the classification problem through the whole notebook.

# %%
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# Let's generate our dataset and take a look on it.

# %%
moons_points, moons_labels = make_moons(n_samples=500, noise=0.2, random_state=42)
plt.scatter(moons_points[:, 0], moons_points[:, 1], c=moons_labels)

# %% [markdown]
# ## 1.1 Pure models.
# First let's try to solve this case with good old Logistic Regression and simple (linear kernel) SVM classifier.
#
# Train LR and SVM classifiers (choose params by hand, no CV or intensive grid search neeeded) and plot their decision regions. Calculate one preffered classification metric.
#
# Describe results in one-two sentences.
#
# _Tip:_ to plot classifiers decisions you colud use either sklearn examples ([this](https://scikit-learn.org/stable/auto_examples/neural_networks/plot_mlp_alpha.html#sphx-glr-auto-examples-neural-networks-plot-mlp-alpha-py) or any other) and mess with matplotlib yourself or great [mlxtend](https://github.com/rasbt/mlxtend) package (see their examples for details)
#
# _Pro Tip:_ wirte function `plot_decisions` taking a dataset and an estimator and plotting the results cause you want to use it several times below

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

from mlxtend.plotting import plot_decision_regions

lr = LogisticRegression() # add some params
svm = SVC(kernel='linear') # here too

### YOUR CODE HERE

# %%
def plot_decisions(X, y, clf):
    clf.fit(X, y)
    plt.figure(figsize=(8, 6))
    plot_decision_regions(X=X, y=y, clf=clf, legend=1)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
models = [
    LogisticRegression(C=5.0, random_state=42, n_jobs=-1),
    SVC(C=1.0, kernel='linear', random_state=42)
]

# %%
X, y = moons_points, moons_labels

# %%
for model in models:
    name = type(model).__name__
    plot_decisions(X, y, model)
    print(name)
# Out:
# LogisticRegression
# SVC

# %% [markdown]
# plot_decisions(X, y, lin_svm)

# %%
from sklearn.model_selection import cross_val_predict

# %%
y_pred_lr = cross_val_predict(log_reg, X, y, cv=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-f8a9bce60c6b> in <module>()
# ----> 1 y_pred_lr = cross_val_predict(log_reg, X, y, cv=3)
#
# NameError: name 'log_reg' is not defined

# %%
y_pred_svm = cross_val_predict(lin_svm, X, y, cv=3)

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred_lr.shape

# %%
y.shape

# %%
accuracy_score(y, y_pred_lr)

# %%
accuracy_score(y, y_pred_svm)

# %%
log_reg.coef_

# %%
log_reg.intercept_

# %%
lin_svm.fit(X, y)

# %%
lin_svm.coef_

# %%
lin_svm.intercept_

# %% [markdown]
# ## 1.2 Kernel tirck
#
# ![keep-calm](https://github.com/girafe-ai/ml-mipt/blob/basic_f20/homeworks_basic/Lab1_ML_pipeline_and_SVM/imgs/keep-calm.jpg?raw=1)
#
# Now use different kernels (`poly`, `rbf`, `sigmoid`) on SVC to get better results. Play `degree` parameter and others.
#
# For each kernel estimate optimal params, plot decision regions, calculate metric you've chosen eariler.
#
# Write couple of sentences on:
#
# * What have happenned with classification quality?
# * How did decision border changed for each kernel?
# * What `degree` have you chosen and why?

# %% [markdown]
# Before using kernel we scale the data:

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_scaled = StandardScaler().fit_transform(X)

# %% [markdown]
# ## RBF

# %%
rbf_svm = SVC(kernel='rbf')

# %%
params_rbf = {
    'gamma': ['scale', 'auto'],
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_cv = GridSearchCV(
    rbf_svm,
    params_rbf,
    cv=5,
    scoring='accuracy'
)

# %% [raw]
# class CustomStandardScaler(StandardScaler):
#
#     #StandardScaler will scale all the features. This custom version allows for chosing the features (columns)
#     #we want to scale.
#     def __init__(self, copy=True, with_mean=True, with_std=True, scaling=True):
#         self.with_mean = with_mean
#         self.with_std = with_std
#         self.copy = copy
#         self.scaling = scaling
#
#     def fit(self, X, y=None):
#         return super().fit(X)
#
#     def transform(self, X, y=None):
#         if self.scaling:
#             return super().transform(X)
#         else:
#             return X
#
#     def fit_transform(self, X, y=None):
#         if self.scaling:
#             super().fit(X)
#             return super().transform(X)
#         else:
#             return X

# %% [raw]
# X_scaled = CustomStandardScaler(scaling=True).fit(X).transform(X)

# %% [raw]
# X_scaled

# %% [raw]
# from sklearn.pipeline import Pipeline

# %% [raw]
# pipeline = Pipeline([
#     ('scaler', CustomStandardScaler()),
#     #('scaler', StandardScaler()),
#     ('rbf_svm', SVC(kernel='linear'))
# ])

# %% [raw]
# params_rbf = {
#     'scaler__scaling': [True, False],
#     'rbf_svm__gamma': ['scale', 'auto'],
# }

# %% [raw]
# grid_cv = GridSearchCV(
#     pipeline,
#     params_rbf,
#     cv=5,
#     scoring='accuracy'
# )

# %% [raw]
# grid_cv.fit(X, y)

# %% [raw]
# grid_cv.best_params_

# %%
grid_cv.fit(X_scaled, y)

# %%
grid_cv.best_score_

# %%
grid_cv.best_params_

# %%
plot_decisions(X_scaled, y, SVC(kernel='rbf', gamma='scale'))

# %% [markdown]
# ## Poly

# %%
poly_svm = SVC(kernel='poly')

# %%
params_poly = {
    'degree': np.arange(2, 5),
    'gamma': ['scale', 'auto'],
    'coef0': np.arange(0, 5, dtype=np.float32),
}

# %%
grid_cv = GridSearchCV(
    poly_svm,
    params_poly,
    cv=5,
    scoring='accuracy'
)

# %%
grid_cv.fit(X_scaled, y)

# %%
grid_cv.best_params_

# %%
grid_cv.best_score_

# %%
plot_decisions(X_scaled, y, grid_cv.best_estimator_)

# %%
import itertools as it

# %%
[(0,0), (1, 0), (0,2)]

# %%
list(it.product([0, 1], repeat=2))

# %% [markdown]
# # Sigmoid

# %%
sig_svm = SVC(kernel='sigmoid')

# %%
params_sig = {
    'C': [1e-3, 1.0, 5.0],
    'gamma': ['scale', 'auto'],
    'coef0': np.arange(0, 5, dtype=np.float32),
}

# %%
grid_cv = GridSearchCV(
    sig_svm,
    params_sig,
    cv=5,
    scoring='accuracy'
)

# %%
grid_cv.fit(X_scaled, y)

# %%
grid_cv.best_params_

# %%
grid_cv.best_score_

# %%
plot_decisions(X_scaled, y, grid_cv.best_estimator_)

# %% [markdown]
# ## 1.3 Simpler solution (of a kind)
# What is we could use Logisitc Regression to successfully solve this task?
#
# Feature generation is a thing to help here. Different techniques of feature generation are used in real life, couple of them will be covered in additional lectures.
#
# In particular case simple `PolynomialFeatures` ([link](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html)) are able to save the day.
#
# Generate the set of new features, train LR on it, plot decision regions, calculate metric.
#
# * Comare SVM's results with this solution (quality, borders type)
# * What degree of PolynomialFeatures have you used? Compare with same SVM kernel parameter.

# %%
from sklearn.preprocessing import PolynomialFeatures

### YOUR CODE HERE

# %%
from sklearn.pipeline import Pipeline

# %%
pipeline = Pipeline(
    [
        ('poly_features', PolynomialFeatures(include_bias=False)),
        ('log_reg', LogisticRegression(C=5.0, random_state=42, n_jobs=-1))
    ]
)

# %%
params_pipe = {
    'poly_features__degree': np.arange(2, 5)
}

# %%
grid_cv = GridSearchCV(
    pipeline,
    params_pipe,
    cv=5,
    scoring='accuracy'
)

# %%
grid_cv.fit(X_scaled, y)

# %%
grid_cv.best_params_

# %%
grid_cv.best_score_

# %%
plot_decisions(X_scaled, y, grid_cv.best_estimator_)

# %% [markdown]
# ## 1.4 Harder problem
#
# Let's make this task a bit more challenging via upgrading dataset:

# %%
from sklearn.datasets import make_circles

circles_points, circles_labels = make_circles(n_samples=500, noise=0.06, random_state=42)

plt.figure(figsize=(5, 5))
plt.scatter(circles_points[:, 0], circles_points[:, 1], c=circles_labels)

# %% [markdown]
# And even more:

# %%
points = np.vstack((circles_points*2.5 + 0.5, moons_points))
labels = np.hstack((circles_labels, moons_labels + 2)) # + 2 to distinct moons classes

plt.figure(figsize=(5, 5))
plt.scatter(points[:, 0], points[:, 1], c=labels)

# %% [markdown]
# Now do your best using all the approaches above!
#
# Tune LR with generated features, SVM with appropriate kernel of your choice. You may add some of your loved models to demonstrate their (and your) strength. Again plot decision regions, calculate metric.
#
# Justify the results in a few phrases.

# %%
X2 = points.copy()
y2 = labels.copy()

# %% [markdown]
# Let's use rbf kernel

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV

# %%
rbf_svm = SVC(kernel='rbf')

# %%
X2_scaled = StandardScaler().fit_transform(X2)

# %%
params_rbf = {
    'C': [1e-3, 1.0, 5.0, 10.0],
    'gamma': ['scale', 'auto'],
}

# %%
grid_cv = GridSearchCV(
    rbf_svm,
    params_rbf,
    cv=5,
    scoring='accuracy'
)

# %%
grid_cv.fit(X2_scaled, y2)
# Out:
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'C': [0.001, 1.0, 5.0, 10.0],
#                          'gamma': ['scale', 'auto']},
#              scoring='accuracy')

# %%
grid_cv.best_params_
# Out:
# {'C': 10.0, 'gamma': 'scale'}

# %%
plt.figure(figsize=(5, 5))
plot_decisions(X2_scaled, y2, grid_cv.best_estimator_)
